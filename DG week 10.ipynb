# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#upload and clean the data

data = pd.read_csv('Test.csv', low_memory = False)

# %%
#renaming columns so easier to understand
data.rename(columns={
    'fecha_dato': 'date',
    'ncodpers': 'customer code',
    'ind_empleado': 'employee index',
    'pais_residencia': 'country',
    'sexo': 'sex',
    'fecha_alta': 'contract date',
    'ind_nuevo': 'customer index',
    'antiguedad': 'customer seniority',
}, inplace=True)

# %%
valid_values = range(0,120)   #age range, set limit to 120 as likely no one older than that

median_value = data['age'].median()     #using median as less sensitive to outliers than mean

for i, value in enumerate(data['age']):
    if value not in valid_values:
        data.at[i, 'indfall'] = 'N'   #mistakenly put as not deceased
        data.at[i, 'age'] = median_value  #for unknown
        
median_value = data['customer index'].median() 
standard_deviation = np.std(data['customer index'])

valid_values = range(int(median_value -3*standard_deviation), int(median_value + 3*standard_deviation) )

for i, value in enumerate(data['customer index']):
    if value not in valid_values:
        data.at[i, 'customer index'] = median_value  #for unknown
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_37800\629770142.py in ?()
#      13 valid_values = range(int(median_value -3*standard_deviation), int(median_value + 3*standard_deviation) )
#      14
#      15 for i, value in enumerate(data['customer index']):
#      16     if value not in valid_values:
# ---> 17         data.at[i, 'customer index'] = median_value  #for unknown
#
# ~\anaconda3\Lib\site-packages\pandas\core\indexing.py in ?(self, key, value)
#    2438
#    2439             self.obj.loc[key] = value
#    2440             return
#    2441
# -> 2442         return super().__setitem__(key, value)
#
# ~\anaconda3\Lib\site-packages\pandas\core\indexing.py in ?(self, key, value)
#    2393         key = list(self._convert_key(key))
#    2394         if len(key) != self.ndim:
# ...

# %%
#checking for values that aren't supposed to be there, replace with P, passive

valid_values = ['N', 'F', 'P', 'B', 'A']
for i, value in enumerate(data['employee index']):
    if value not in valid_values:
        data.at[i, 'employee index'] = 'U'   #for unknown
        
valid_values = [1, 2, 3, 4, 'P']
for i, value in enumerate(data['indrel_1mes']):
    if value not in valid_values:
        data.at[i, 'indrel_1mes'] = 'U'   #for unknown
        
valid_values = ['S', 'N']
for i, value in enumerate(data['indresi']):
    if value not in valid_values:
        print(value)   #no missing data
        
valid_values = ['S', 'N']
for i, value in enumerate(data['indext']):
    if value not in valid_values:
        print(value)   #no missing data

valid_values = [1, 0]   #for spouse employee
for i, value in enumerate(data['conyuemp']):
    if value not in valid_values:
        data.at[i, 'conyuemp'] = 'U'  #to indicate unknown
        
valid_values = ['V', 'H']
for i, value in enumerate(data['sex']):
    if value not in valid_values:
        data.at[i, 'sex'] = 'U'  #to indicate unknown

# %%
#now start the EDA

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 929615 entries, 0 to 929614
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   date                   929615 non-null  object
#  1   customer code          929615 non-null  int64
#  2   employee index         929615 non-null  object
#  3   country                929615 non-null  object
#  4   sex                    929610 non-null  object
#  5   age                    929615 non-null  int64
#  6   contract date          929615 non-null  object
#  7   customer index         929615 non-null  int64
#  8   customer seniority     929615 non-null  int64
#  9   indrel                 929615 non-null  int64
#  10  ult_fec_cli_1t         1683 non-null    object
#  11  indrel_1mes            929592 non-null  float64
#  12  tiprel_1mes            929592 non-null  object
#  13  indresi                929615 non-null  object
# ...

# %% [markdown]
# * ind_hip_fin_ult1	<br>
# Mortgage <br>
# * ind_plan_fin_ult1 <br>
# Pensions <br>
# * ind_pres_fin_ult1	<br>
# Loans
# * ind_reca_fin_ult1	<br>
# Taxes
# * ind_tjcr_fin_ult1	<br>
# Credit Card
# * ind_valo_fin_ult1	<br>
# Securities
# * ind_viv_fin_ult1	<br>
# Home Account
# * ind_nomina_ult1	<br>
# Payroll
# * ind_nom_pens_ult1	<br>
# Pensions
# * ind_recibo_ult1	<br>
# Direct Debit

# %%
#looking at link between age and if there is a credit card

color = ['Deeppink', 'Yellow']
age_plot = sns.catplot(data=customers_cab_data, x="Age Groups", kind = 'count', hue="Company",col = "Year", palette = color)
age_plot.set(ylabel='Number of Customers')
#sns.palplot(sns.color_palette("deep", 10))
plt.show()

# %%
data['Age Groups'] = pd.cut(data['age'], bins=[18, 32, 49, 65], labels=['18-32', '33-49', '50-65'])
grouped_data['Company'] = grouped_data.index

# %%
data
# Out:
#               date  customer code employee index country sex  age  \
# 0       2016-06-28          15889              F      ES   V   56
# 1       2016-06-28        1170544              N      ES   H   36
# 2       2016-06-28        1170545              N      ES   V   22
# 3       2016-06-28        1170547              N      ES   H   22
# 4       2016-06-28        1170548              N      ES   H   22
# ...            ...            ...            ...     ...  ..  ...
# 929610  2016-06-28         660237              N      ES   V   55
# 929611  2016-06-28         660238              N      ES   V   30
# 929612  2016-06-28         660240              N      ES   V   52
# 929613  2016-06-28         660243              N      ES   V   32
# 929614  2016-06-28         660248              N      ES   V   92
#
#        contract date  customer index  customer seniority  indrel  ...  \
# 0         1995-01-16               0                 256       1  ...
# ...
